# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/used_car_price/train_set_label.csv")

# %%
train_data.head()
# Out:
#              region                         region_url    year manufacturer  \
# 0       san antonio  https://sanantonio.craigslist.org  2018.0        honda
# 1           augusta     https://augusta.craigslist.org  2006.0         ford
# 2  hickory / lenoir     https://hickory.craigslist.org     NaN          NaN
# 3  fargo / moorhead       https://fargo.craigslist.org     NaN          NaN
# 4       los angeles  https://losangeles.craigslist.org     NaN          NaN
#
#                model_name car_condition #cylinders fuel_type  odometer  \
# 0             accord ex-l           NaN        NaN       gas       NaN
# 1  f250 super duty diesel     excellent        NaN    diesel  169438.0
# 2                     NaN           NaN        NaN       NaN       NaN
# 3                     NaN           NaN        NaN       NaN       NaN
# 4                     NaN           NaN        NaN       NaN       NaN
#
#   title_status  ...       size car_type car_color  \
# 0        clean  ...        NaN      NaN       NaN
# 1        clean  ...  full-size    truck     white
# 2          NaN  ...        NaN      NaN       NaN
# 3          NaN  ...        NaN      NaN       NaN
# 4          NaN  ...        NaN      NaN       NaN
#
#                                            image_url  \
# 0  https://images.craigslist.org/00W0W_jPnECYbxWm...
# 1  https://images.craigslist.org/00U0U_5ROtvUdu72...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      car_description county state latitude  \
# 0  Price: $24,900 Miles: 31,269 Engine: 1.5L Turb...    NaN    tx  29.5407
# 1  2006 Ford F250 Lariat SuperDuty Crew Cab 4 doo...    NaN    ga  33.5161
# 2                                                NaN    NaN    nc      NaN
# 3                                                NaN    NaN    mn      NaN
# 4                                                NaN    NaN    ca      NaN
#
#    longitude price_of_car
# 0   -98.5521        24900
# 1   -82.0785            0
# 2        NaN         4500
# 3        NaN        20000
# 4        NaN            0
#
# [5 rows x 23 columns]

# %%
train_data.shape
# Out:
# (37500, 23)

# %%
train_data.to_csv("train_data.csv")

# %%
df = pd.read_csv("train_data.csv")
df.head()
# Out:
#    Unnamed: 0            region                         region_url    year  \
# 0           0       san antonio  https://sanantonio.craigslist.org  2018.0
# 1           1           augusta     https://augusta.craigslist.org  2006.0
# 2           2  hickory / lenoir     https://hickory.craigslist.org     NaN
# 3           3  fargo / moorhead       https://fargo.craigslist.org     NaN
# 4           4       los angeles  https://losangeles.craigslist.org     NaN
#
#   manufacturer              model_name car_condition #cylinders fuel_type  \
# 0        honda             accord ex-l           NaN        NaN       gas
# 1         ford  f250 super duty diesel     excellent        NaN    diesel
# 2          NaN                     NaN           NaN        NaN       NaN
# 3          NaN                     NaN           NaN        NaN       NaN
# 4          NaN                     NaN           NaN        NaN       NaN
#
#    odometer  ...       size car_type car_color  \
# 0       NaN  ...        NaN      NaN       NaN
# 1  169438.0  ...  full-size    truck     white
# 2       NaN  ...        NaN      NaN       NaN
# 3       NaN  ...        NaN      NaN       NaN
# 4       NaN  ...        NaN      NaN       NaN
#
#                                            image_url  \
# 0  https://images.craigslist.org/00W0W_jPnECYbxWm...
# 1  https://images.craigslist.org/00U0U_5ROtvUdu72...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      car_description county state latitude  \
# 0  Price: $24,900 Miles: 31,269 Engine: 1.5L Turb...    NaN    tx  29.5407
# 1  2006 Ford F250 Lariat SuperDuty Crew Cab 4 doo...    NaN    ga  33.5161
# 2                                                NaN    NaN    nc      NaN
# 3                                                NaN    NaN    mn      NaN
# 4                                                NaN    NaN    ca      NaN
#
#   longitude  price_of_car
# 0  -98.5521         24900
# 1  -82.0785             0
# 2       NaN          4500
# 3       NaN         20000
# 4       NaN             0
#
# [5 rows x 24 columns]

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#              region                         region_url    year manufacturer  \
# 0       san antonio  https://sanantonio.craigslist.org  2018.0        honda
# 1           augusta     https://augusta.craigslist.org  2006.0         ford
# 2  hickory / lenoir     https://hickory.craigslist.org     NaN          NaN
# 3  fargo / moorhead       https://fargo.craigslist.org     NaN          NaN
# 4       los angeles  https://losangeles.craigslist.org     NaN          NaN
#
#                model_name car_condition #cylinders fuel_type  odometer  \
# 0             accord ex-l           NaN        NaN       gas       NaN
# 1  f250 super duty diesel     excellent        NaN    diesel  169438.0
# 2                     NaN           NaN        NaN       NaN       NaN
# 3                     NaN           NaN        NaN       NaN       NaN
# 4                     NaN           NaN        NaN       NaN       NaN
#
#   title_status  ...       size car_type car_color  \
# 0        clean  ...        NaN      NaN       NaN
# 1        clean  ...  full-size    truck     white
# 2          NaN  ...        NaN      NaN       NaN
# 3          NaN  ...        NaN      NaN       NaN
# 4          NaN  ...        NaN      NaN       NaN
#
#                                            image_url  \
# 0  https://images.craigslist.org/00W0W_jPnECYbxWm...
# 1  https://images.craigslist.org/00U0U_5ROtvUdu72...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      car_description county state latitude  \
# 0  Price: $24,900 Miles: 31,269 Engine: 1.5L Turb...    NaN    tx  29.5407
# 1  2006 Ford F250 Lariat SuperDuty Crew Cab 4 doo...    NaN    ga  33.5161
# 2                                                NaN    NaN    nc      NaN
# 3                                                NaN    NaN    mn      NaN
# 4                                                NaN    NaN    ca      NaN
#
#    longitude price_of_car
# 0   -98.5521        24900
# 1   -82.0785            0
# 2        NaN         4500
# 3        NaN        20000
# 4        NaN            0
#
# [5 rows x 23 columns]

# %%
null_sum = df.isnull().sum()
null_sum
# Out:
# region                 0
# region_url             0
# year               15975
# manufacturer       16896
# model_name         16174
# car_condition      26360
# #cylinders         24668
# fuel_type          16091
# odometer           19929
# title_status       16032
# transmission       15997
# vin                25480
# drive              22558
# size               30952
# car_type           21326
# car_color          23122
# image_url          15899
# car_description    15899
# county             37500
# state                  0
# latitude           16268
# longitude          16268
# price_of_car           0
# dtype: int64

# %%
def null_percentage(df):
    for i,name in enumerate(df.columns):
        if null_sum[i] > 0:
            print(f"The Percentage of Null Values in {name} is {(null_sum[i]/df.shape[0])*100} %")

# %%
null_percentage(df)
# Out:
# The Percentage of Null Values in year is 42.6 %
# The Percentage of Null Values in manufacturer is 45.056000000000004 %
# The Percentage of Null Values in model_name is 43.13066666666667 %
# The Percentage of Null Values in car_condition is 70.29333333333334 %
# The Percentage of Null Values in #cylinders is 65.78133333333334 %
# The Percentage of Null Values in fuel_type is 42.909333333333336 %
# The Percentage of Null Values in odometer is 53.144000000000005 %
# The Percentage of Null Values in title_status is 42.752 %
# The Percentage of Null Values in transmission is 42.65866666666667 %
# The Percentage of Null Values in vin is 67.94666666666667 %
# The Percentage of Null Values in drive is 60.15466666666667 %
# The Percentage of Null Values in size is 82.53866666666667 %
# The Percentage of Null Values in car_type is 56.86933333333334 %
# The Percentage of Null Values in car_color is 61.65866666666666 %
# The Percentage of Null Values in image_url is 42.39733333333333 %
# The Percentage of Null Values in car_description is 42.39733333333333 %
# The Percentage of Null Values in county is 100.0 %
# The Percentage of Null Values in latitude is 43.38133333333333 %
# The Percentage of Null Values in longitude is 43.38133333333333 %
